# %% [markdown]
# # Step 0: set work directories, extract paths, summarize

# %%
import os
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
import scipy.io as scio
from collections import OrderedDict 
import numpy as np
import pandas as pd
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
from sklearn.metrics import classification_report
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import scale
from time import time

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)
print("Auth Success")
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# Auth Success

# %% [markdown]
# First upload train_set.zip in data folder to google drive, and please replace the *id* of the zip file. (By right-clicking the train_set.zip file in the google drive and selecting "Get Sharable Link", you can get an ID.)

# %%
download = drive.CreateFile({'id': '1VnzsmUSgP_IqXvlgWMCVPpbPW665fjaI'}) #please replace the id of your file
download.GetContentFile('train_set.zip')
# !unzip train_set.zip
# Out:
# Archive:  train_set.zip
#    creating: train_set/
#   inflating: train_set/.DS_Store
#    creating: __MACOSX/
#    creating: __MACOSX/train_set/
#   inflating: __MACOSX/train_set/._.DS_Store
#    creating: train_set/images/
#   inflating: train_set/images/0071.jpg
#    creating: __MACOSX/train_set/images/
#   inflating: __MACOSX/train_set/images/._0071.jpg
#   inflating: train_set/images/2100.jpg
#   inflating: __MACOSX/train_set/images/._2100.jpg
#   inflating: train_set/images/0717.jpg
#   inflating: __MACOSX/train_set/images/._0717.jpg
#   inflating: train_set/images/1409.jpg
#   inflating: __MACOSX/train_set/images/._1409.jpg
#   inflating: train_set/images/0703.jpg
#   inflating: __MACOSX/train_set/images/._0703.jpg
#   inflating: train_set/images/2114.jpg
#   inflating: __MACOSX/train_set/images/._2114.jpg
#   inflating: train_set/images/0065.jpg
#   inflating: __MACOSX/train_set/images/._0065.jpg
#   inflating: train_set/images/1353.jpg
#   inflating: __MACOSX/train_set/images/._1353.jpg
#   inflating: train_set/images/1435.jpg
#   inflating: __MACOSX/train_set/images/._1435.jpg
#   inflating: train_set/images/2128.jpg
#   inflating: __MACOSX/train_set/images/._2128.jpg
#   inflating: train_set/images/1421.jpg
#   inflating: __MACOSX/train_set/images/._1421.jpg
#   inflating: train_set/images/1347.jpg
#   inflating: __MACOSX/train_set/images/._1347.jpg
#   inflating: train_set/images/0059.jpg
#   inflating: __MACOSX/train_set/images/._0059.jpg
#   inflating: train_set/images/0918.jpg
#   inflating: __MACOSX/train_set/images/._0918.jpg
#   inflating: train_set/images/1390.jpg
#   inflating: __MACOSX/train_set/images/._1390.jpg
#   inflating: train_set/images/0930.jpg
#   inflating: __MACOSX/train_set/images/._0930.jpg
#   inflating: train_set/images/0924.jpg
#   inflating: __MACOSX/train_set/images/._0924.jpg
#   inflating: train_set/images/1384.jpg
#   inflating: __MACOSX/train_set/images/._1384.jpg
#   inflating: train_set/images/0515.jpg
#   inflating: __MACOSX/train_set/images/._0515.jpg
#   inflating: train_set/images/2302.jpg
#   inflating: __MACOSX/train_set/images/._2302.jpg
#   inflating: train_set/images/2464.jpg
#   inflating: __MACOSX/train_set/images/._2464.jpg
#   inflating: train_set/images/0273.jpg
#   inflating: __MACOSX/train_set/images/._0273.jpg
#   inflating: train_set/images/0267.jpg
#   inflating: __MACOSX/train_set/images/._0267.jpg
#   inflating: train_set/images/1179.jpg
#   inflating: __MACOSX/train_set/images/._1179.jpg
#   inflating: train_set/images/2470.jpg
#   inflating: __MACOSX/train_set/images/._2470.jpg
#   inflating: train_set/images/2316.jpg
#   inflating: __MACOSX/train_set/images/._1829.jpg
#   inflating: train_set/images/1183.jpg
#   inflating: __MACOSX/train_set/images/._1183.jpg
#   inflating: train_set/images/1815.jpg
#   inflating: __MACOSX/train_set/images/._1815.jpg
#   inflating: train_set/images/1801.jpg
#   inflating: __MACOSX/train_set/images/._1801.jpg
#   inflating: train_set/images/1020.jpg
#   inflating: __MACOSX/train_set/images/._1020.jpg
#   inflating: train_set/images/0458.jpg
#   inflating: __MACOSX/train_set/images/._0458.jpg
#   inflating: train_set/images/1746.jpg
#   inflating: __MACOSX/train_set/images/._1746.jpg
#   inflating: train_set/images/1752.jpg
#   inflating: __MACOSX/train_set/images/._1752.jpg
#   inflating: train_set/images/1034.jpg
#   inflating: __MACOSX/train_set/images/._1034.jpg
#   inflating: train_set/images/0302.jpg
#   inflating: __MACOSX/train_set/images/._0302.jpg
#   inflating: train_set/images/0464.jpg
#   inflating: __MACOSX/train_set/images/._0464.jpg
#   inflating: train_set/images/2273.jpg
#   inflating: __MACOSX/train_set/images/._2273.jpg
#   inflating: train_set/images/2267.jpg
#   inflating: __MACOSX/train_set/images/._2267.jpg
#   inflating: train_set/images/0470.jpg
#   inflating: __MACOSX/train_set/images/._0470.jpg
#   inflating: train_set/images/1008.jpg
#   inflating: __MACOSX/train_set/images/._1008.jpg
#   inflating: train_set/images/0316.jpg
#   inflating: __MACOSX/train_set/images/._0316.jpg
#   inflating: train_set/images/1785.jpg
#   inflating: __MACOSX/train_set/images/._1785.jpg
#   inflating: train_set/images/2298.jpg
#   inflating: __MACOSX/train_set/images/._2298.jpg
#   inflating: train_set/images/1791.jpg
#   inflating: __MACOSX/train_set/images/._1791.jpg
#   inflating: train_set/images/1949.jpg
#   inflating: __MACOSX/train_set/images/._1949.jpg
#   inflating: train_set/images/1961.jpg
#   inflating: __MACOSX/train_set/images/._1961.jpg
# ...
#   inflating: train_set/points/0378.mat
#   inflating: __MACOSX/train_set/points/._0378.mat
#   inflating: train_set/points/1066.mat
#   inflating: __MACOSX/train_set/points/._1066.mat
#   inflating: train_set/points/1700.mat
#   inflating: __MACOSX/train_set/points/._1700.mat
#   inflating: train_set/points/2209.mat
#   inflating: __MACOSX/train_set/points/._2209.mat
#   inflating: train_set/points/1933.mat
#   inflating: __MACOSX/train_set/points/._1933.mat
#   inflating: train_set/points/0393.mat
#   inflating: __MACOSX/train_set/points/._0393.mat
#   inflating: train_set/points/1099.mat
#   inflating: __MACOSX/train_set/points/._1099.mat
#   inflating: train_set/points/0387.mat
#   inflating: __MACOSX/train_set/points/._0387.mat
#   inflating: train_set/points/1927.mat
#   inflating: __MACOSX/train_set/points/._1927.mat
#   inflating: train_set/points/1919.mat
#   inflating: __MACOSX/train_set/points/._1919.mat
#   inflating: train_set/points/0391.mat
#   inflating: __MACOSX/train_set/points/._0391.mat
#   inflating: train_set/points/1931.mat
#   inflating: __MACOSX/train_set/points/._1931.mat
#   inflating: train_set/points/1925.mat
#   inflating: __MACOSX/train_set/points/._1925.mat
#   inflating: train_set/points/0385.mat
#   inflating: __MACOSX/train_set/points/._0385.mat
#   inflating: train_set/points/1070.mat
#   inflating: __MACOSX/train_set/points/._1070.mat
#   inflating: train_set/points/0408.mat
#   inflating: __MACOSX/train_set/points/._0408.mat
#   inflating: train_set/points/1716.mat
#   inflating: __MACOSX/train_set/points/._1716.mat
#   inflating: train_set/points/1702.mat
#   inflating: __MACOSX/train_set/points/._1702.mat
#   inflating: train_set/points/1064.mat
#   inflating: __MACOSX/train_set/points/._1064.mat
#   inflating: train_set/points/0352.mat
#   inflating: __MACOSX/train_set/points/._0352.mat
#   inflating: train_set/points/2223.mat
#   inflating: __MACOSX/train_set/points/._2223.mat
#   inflating: train_set/points/0434.mat
#   inflating: __MACOSX/train_set/points/._0434.mat
#   inflating: train_set/points/0420.mat
#   inflating: __MACOSX/train_set/points/._0420.mat
#   inflating: train_set/points/2237.mat
#   inflating: __MACOSX/train_set/points/._2237.mat
#   inflating: train_set/points/1058.mat
#   inflating: __MACOSX/train_set/points/._1058.mat
#   inflating: train_set/points/0346.mat
#   inflating: __MACOSX/train_set/points/._0346.mat
#   inflating: train_set/points/0811.mat
#   inflating: __MACOSX/train_set/points/._0811.mat
#   inflating: train_set/points/0805.mat
#   inflating: __MACOSX/train_set/points/._0805.mat
#   inflating: train_set/points/0193.mat
#   inflating: __MACOSX/train_set/points/._0193.mat
#   inflating: train_set/points/1299.mat
#   inflating: __MACOSX/train_set/points/._1299.mat
#   inflating: train_set/points/0187.mat
#   inflating: __MACOSX/train_set/points/._0187.mat
#   inflating: train_set/points/0839.mat
#   inflating: __MACOSX/train_set/points/._0839.mat
#   inflating: train_set/points/1514.mat
#   inflating: __MACOSX/train_set/points/._1514.mat
#   inflating: train_set/points/1272.mat
#   inflating: __MACOSX/train_set/points/._1272.mat
#   inflating: train_set/points/0178.mat
#   inflating: __MACOSX/train_set/points/._0178.mat
#   inflating: train_set/points/1266.mat
#   inflating: __MACOSX/train_set/points/._1266.mat
#   inflating: train_set/points/1500.mat
#   inflating: __MACOSX/train_set/points/._1500.mat
#   inflating: train_set/points/2009.mat
#   inflating: __MACOSX/train_set/points/._2009.mat
#   inflating: train_set/points/1528.mat
#   inflating: __MACOSX/train_set/points/._1528.mat
#   inflating: train_set/points/0636.mat
#   inflating: __MACOSX/train_set/points/._0636.mat
#   inflating: train_set/points/2021.mat
#   inflating: __MACOSX/train_set/points/._2021.mat
#   inflating: train_set/points/0150.mat
#   inflating: __MACOSX/train_set/points/._0150.mat
#   inflating: train_set/points/0144.mat
#   inflating: __MACOSX/train_set/points/._0144.mat
#   inflating: train_set/points/2035.mat
#   inflating: __MACOSX/train_set/points/._2035.mat
#   inflating: train_set/points/0622.mat
#   inflating: __MACOSX/train_set/points/._0622.mat
#   inflating: train_set/points/0965.mat
#   inflating: __MACOSX/train_set/points/._0965.mat
#   inflating: train_set/points/0971.mat
#   inflating: __MACOSX/train_set/points/._0971.mat
#   inflating: train_set/points/2196.mat
#   inflating: __MACOSX/train_set/points/._2196.mat
#   inflating: train_set/points/0959.mat
#   inflating: __MACOSX/train_set/points/._0959.mat
#   inflating: train_set/points/0781.mat
#   inflating: __MACOSX/train_set/points/._0781.mat
#   inflating: train_set/points/0795.mat
#   inflating: __MACOSX/train_set/points/._0795.mat
#   inflating: train_set/points/2182.mat
#   inflating: __MACOSX/train_set/points/._2182.mat
#   inflating: train_set/points/2169.mat
#   inflating: __MACOSX/train_set/points/._2169.mat
#   inflating: train_set/points/1460.mat
#   inflating: __MACOSX/train_set/points/._1460.mat
#   inflating: train_set/points/1306.mat
#   inflating: __MACOSX/train_set/points/._1306.mat
#   inflating: train_set/points/0018.mat
#   inflating: __MACOSX/train_set/points/._0018.mat
#   inflating: train_set/points/1312.mat
#   inflating: __MACOSX/train_set/points/._1312.mat
#   inflating: train_set/points/1474.mat
#   inflating: __MACOSX/train_set/points/._1474.mat
#   inflating: train_set/points/0742.mat
#   inflating: __MACOSX/train_set/points/._0742.mat
#   inflating: train_set/points/2155.mat
#   inflating: __MACOSX/train_set/points/._2155.mat
#   inflating: train_set/points/0024.mat
#   inflating: __MACOSX/train_set/points/._0024.mat
#   inflating: train_set/points/0030.mat
#   inflating: __MACOSX/train_set/points/._0030.mat
#   inflating: train_set/points/2141.mat
#   inflating: __MACOSX/train_set/points/._2141.mat
#   inflating: train_set/points/0756.mat
#   inflating: __MACOSX/train_set/points/._0756.mat
#   inflating: train_set/points/1448.mat
#   inflating: __MACOSX/train_set/points/._1448.mat
#   inflating: train_set/points/1879.mat
#   inflating: __MACOSX/train_set/points/._1879.mat
#   inflating: train_set/points/0583.mat
#   inflating: __MACOSX/train_set/points/._0583.mat
#   inflating: train_set/points/1845.mat
#   inflating: __MACOSX/train_set/points/._1845.mat
#   inflating: train_set/points/2394.mat
#   inflating: __MACOSX/train_set/points/._2394.mat
#   inflating: train_set/points/2380.mat
#   inflating: __MACOSX/train_set/points/._2380.mat
#   inflating: train_set/points/0597.mat
#   inflating: __MACOSX/train_set/points/._0597.mat
#   inflating: train_set/points/1851.mat
#   inflating: __MACOSX/train_set/points/._1851.mat
#   inflating: train_set/points/1689.mat
#   inflating: __MACOSX/train_set/points/._1689.mat
#   inflating: train_set/points/1104.mat
#   inflating: __MACOSX/train_set/points/._1104.mat
#   inflating: train_set/points/1662.mat
#   inflating: __MACOSX/train_set/points/._1662.mat
#   inflating: train_set/points/1676.mat
#   inflating: __MACOSX/train_set/points/._1676.mat
#   inflating: train_set/points/0568.mat
#   inflating: __MACOSX/train_set/points/._0568.mat
#   inflating: train_set/points/1110.mat
#   inflating: __MACOSX/train_set/points/._1110.mat
#   inflating: train_set/points/2419.mat
#   inflating: __MACOSX/train_set/points/._2419.mat
#   inflating: train_set/points/0226.mat
#   inflating: __MACOSX/train_set/points/._0226.mat
#   inflating: train_set/points/1138.mat
#   inflating: __MACOSX/train_set/points/._1138.mat
#   inflating: train_set/points/2431.mat
#   inflating: __MACOSX/train_set/points/._2431.mat
#   inflating: train_set/points/2357.mat
#   inflating: __MACOSX/train_set/points/._2357.mat
#   inflating: train_set/points/0540.mat
#   inflating: __MACOSX/train_set/points/._0540.mat
#   inflating: train_set/points/1886.mat
#   inflating: __MACOSX/train_set/points/._1886.mat
#   inflating: train_set/points/0554.mat
#   inflating: __MACOSX/train_set/points/._0554.mat
#   inflating: train_set/points/1892.mat
#   inflating: __MACOSX/train_set/points/._1892.mat
#   inflating: train_set/points/2343.mat
#   inflating: __MACOSX/train_set/points/._2343.mat
#   inflating: train_set/points/2425.mat
#   inflating: __MACOSX/train_set/points/._2425.mat
#   inflating: train_set/points/0232.mat
#   inflating: __MACOSX/train_set/points/._0232.mat
#   inflating: train_set/points/2342.mat
#   inflating: __MACOSX/train_set/points/._2342.mat
#   inflating: train_set/points/1893.mat
#   inflating: __MACOSX/train_set/points/._1893.mat
#   inflating: train_set/points/0555.mat
#   inflating: __MACOSX/train_set/points/._0555.mat
#   inflating: train_set/points/0233.mat
#   inflating: __MACOSX/train_set/points/._0233.mat
#   inflating: train_set/points/2424.mat
#   inflating: __MACOSX/train_set/points/._2424.mat
#   inflating: train_set/points/2430.mat
#   inflating: __MACOSX/train_set/points/._2430.mat
#   inflating: train_set/points/1139.mat
#   inflating: __MACOSX/train_set/points/._1139.mat
#   inflating: train_set/points/0227.mat
#   inflating: __MACOSX/train_set/points/._0227.mat
#   inflating: train_set/points/1887.mat
#   inflating: __MACOSX/train_set/points/._1887.mat
#   inflating: train_set/points/0541.mat
#   inflating: __MACOSX/train_set/points/._0541.mat
#   inflating: train_set/points/2356.mat
#   inflating: __MACOSX/train_set/points/._2356.mat
#   inflating: train_set/points/0569.mat
#   inflating: __MACOSX/train_set/points/._0569.mat
#   inflating: train_set/points/1677.mat
#   inflating: __MACOSX/train_set/points/._1677.mat
#   inflating: train_set/points/2418.mat
#   inflating: __MACOSX/train_set/points/._2418.mat
#   inflating: train_set/points/1111.mat
#   inflating: __MACOSX/train_set/points/._1111.mat
#   inflating: train_set/points/1105.mat
#   inflating: __MACOSX/train_set/points/._1105.mat
#   inflating: train_set/points/1663.mat
#   inflating: __MACOSX/train_set/points/._1663.mat
#   inflating: train_set/points/1688.mat
#   inflating: __MACOSX/train_set/points/._1688.mat
#   inflating: train_set/points/1850.mat
#   inflating: __MACOSX/train_set/points/._1850.mat
#   inflating: train_set/points/0596.mat
#   inflating: __MACOSX/train_set/points/._0596.mat
#   inflating: train_set/points/2381.mat
#   inflating: __MACOSX/train_set/points/._2381.mat
#   inflating: train_set/points/2395.mat
#   inflating: __MACOSX/train_set/points/._2395.mat
#   inflating: train_set/points/1844.mat
#   inflating: __MACOSX/train_set/points/._1844.mat
#   inflating: train_set/points/0582.mat
#   inflating: __MACOSX/train_set/points/._0582.mat
#   inflating: train_set/points/1878.mat
#   inflating: __MACOSX/train_set/points/._1878.mat
#   inflating: train_set/points/0031.mat
#   inflating: __MACOSX/train_set/points/._0031.mat
#   inflating: train_set/points/1449.mat
#   inflating: __MACOSX/train_set/points/._1449.mat
#   inflating: train_set/points/0757.mat
#   inflating: __MACOSX/train_set/points/._0757.mat
#   inflating: train_set/points/2140.mat
#   inflating: __MACOSX/train_set/points/._2140.mat
#   inflating: train_set/points/2154.mat
#   inflating: __MACOSX/train_set/points/._2154.mat
#   inflating: train_set/points/0743.mat
#   inflating: __MACOSX/train_set/points/._0743.mat
#   inflating: train_set/points/0025.mat
#   inflating: __MACOSX/train_set/points/._0025.mat
#   inflating: train_set/points/1313.mat
#   inflating: __MACOSX/train_set/points/._1313.mat
#   inflating: train_set/points/1475.mat
#   inflating: __MACOSX/train_set/points/._1475.mat
#   inflating: train_set/points/1461.mat
#   inflating: __MACOSX/train_set/points/._1461.mat
#   inflating: train_set/points/2168.mat
#   inflating: __MACOSX/train_set/points/._2168.mat
#   inflating: train_set/points/0019.mat
#   inflating: __MACOSX/train_set/points/._0019.mat
#   inflating: train_set/points/1307.mat
#   inflating: __MACOSX/train_set/points/._1307.mat
#   inflating: train_set/points/2183.mat
#   inflating: __MACOSX/train_set/points/._2183.mat
#   inflating: train_set/points/0794.mat
#   inflating: __MACOSX/train_set/points/._0794.mat
#   inflating: train_set/points/0780.mat
#   inflating: __MACOSX/train_set/points/._0780.mat
#   inflating: train_set/points/0958.mat
#   inflating: __MACOSX/train_set/points/._0958.mat
#   inflating: train_set/points/2197.mat
#   inflating: __MACOSX/train_set/points/._2197.mat
#   inflating: train_set/points/0970.mat
#   inflating: __MACOSX/train_set/points/._0970.mat
#   inflating: train_set/points/0964.mat
#   inflating: __MACOSX/train_set/points/._0964.mat
#   inflating: train_set/points/0145.mat
#   inflating: __MACOSX/train_set/points/._0145.mat
#   inflating: train_set/points/0623.mat
#   inflating: __MACOSX/train_set/points/._0623.mat
#   inflating: train_set/points/2034.mat
#   inflating: __MACOSX/train_set/points/._2034.mat
#   inflating: train_set/points/2020.mat
#   inflating: __MACOSX/train_set/points/._2020.mat
#   inflating: train_set/points/0637.mat
#   inflating: __MACOSX/train_set/points/._0637.mat
#   inflating: train_set/points/1529.mat
#   inflating: __MACOSX/train_set/points/._1529.mat
#   inflating: train_set/points/0151.mat
#   inflating: __MACOSX/train_set/points/._0151.mat
#   inflating: train_set/points/1267.mat
#   inflating: __MACOSX/train_set/points/._1267.mat
#   inflating: train_set/points/0179.mat
#   inflating: __MACOSX/train_set/points/._0179.mat
#   inflating: train_set/points/2008.mat
#   inflating: __MACOSX/train_set/points/._2008.mat
#   inflating: train_set/points/1501.mat
#   inflating: __MACOSX/train_set/points/._1501.mat
#   inflating: train_set/points/1515.mat
#   inflating: __MACOSX/train_set/points/._1515.mat
#   inflating: train_set/points/1273.mat
#   inflating: __MACOSX/train_set/points/._1273.mat
#   inflating: train_set/points/0186.mat
#   inflating: __MACOSX/train_set/points/._0186.mat
#   inflating: train_set/points/1298.mat
#   inflating: __MACOSX/train_set/points/._1298.mat
#   inflating: train_set/points/0838.mat
#   inflating: __MACOSX/train_set/points/._0838.mat
#   inflating: train_set/points/0192.mat
#   inflating: __MACOSX/train_set/points/._0192.mat
#   inflating: train_set/points/0804.mat
#   inflating: __MACOSX/train_set/points/._0804.mat
#   inflating: train_set/points/0810.mat
#   inflating: __MACOSX/train_set/points/._0810.mat
#   inflating: train_set/points/2236.mat
#   inflating: __MACOSX/train_set/points/._2236.mat
#   inflating: train_set/points/0421.mat
#   inflating: __MACOSX/train_set/points/._0421.mat
#   inflating: train_set/points/0347.mat
#   inflating: __MACOSX/train_set/points/._0347.mat
#   inflating: train_set/points/1059.mat
#   inflating: __MACOSX/train_set/points/._1059.mat
#   inflating: train_set/points/0353.mat
#   inflating: __MACOSX/train_set/points/._0353.mat
#   inflating: train_set/points/0435.mat
#   inflating: __MACOSX/train_set/points/._0435.mat
#   inflating: train_set/points/2222.mat
#   inflating: __MACOSX/train_set/points/._2222.mat
#   inflating: train_set/points/1703.mat
#   inflating: __MACOSX/train_set/points/._1703.mat
#   inflating: train_set/points/1065.mat
#   inflating: __MACOSX/train_set/points/._1065.mat
#   inflating: train_set/points/1071.mat
#   inflating: __MACOSX/train_set/points/._1071.mat
#   inflating: train_set/points/1717.mat
#   inflating: __MACOSX/train_set/points/._1717.mat
#   inflating: train_set/points/0409.mat
#   inflating: __MACOSX/train_set/points/._0409.mat
#   inflating: train_set/points/1924.mat
#   inflating: __MACOSX/train_set/points/._1924.mat
#   inflating: train_set/points/0384.mat
#   inflating: __MACOSX/train_set/points/._0384.mat
#   inflating: train_set/points/0390.mat
#   inflating: __MACOSX/train_set/points/._0390.mat
#   inflating: train_set/points/1930.mat
#   inflating: __MACOSX/train_set/points/._1930.mat
#   inflating: train_set/points/1918.mat
#   inflating: __MACOSX/train_set/points/._1918.mat
#   inflating: __MACOSX/train_set/._points
#   inflating: __MACOSX/._train_set

# %% [markdown]
# # Step 1: set up controls for evaluation experiments.

# %%
import pandas as pd
import numpy as np
import time
from sklearn.ensemble import GradientBoostingClassifier  #GBM algorithm
from sklearn import metrics
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split, GridSearchCV #Perforing grid search
import matplotlib.pylab as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 12, 4

# %% [markdown]
# # Step 2: import data and train-test split

# %%
########## Importing the fidusial points ##########
import scipy.io as scio
from collections import OrderedDict 
points_path = 'train_set/points'
points = [p for p in sorted(os.listdir(points_path))]
all_points = []
for p in points:
  poiFile = os.path.join(points_path, p)
  poi = scio.loadmat(poiFile)
  poi = OrderedDict(poi)
  all_points.append(poi.popitem()[1])
y = pd.read_csv('train_set/label.csv')['emotion_idx']

print('success')
# Out:
# success

# %% [markdown]
# # Step 3: construct features and responses

# %%
########## Calculating pairwise distance ##########
pair_dist = []
for i in range(len(all_points)):
  pair_dist.append(metrics.pairwise_distances(all_points[i])[np.triu_indices(78)])

########## Split train_set & test_set ##########
points_train, points_test, y_train, y_test = train_test_split(pair_dist, y, random_state=42, test_size=0.2)
print('success')
# Out:
# success

# %% [markdown]
# # Step 4: Train a classification model with training features and responses

# %% [markdown]
# ## GBM & CV (Baseline Model)

# %%
start = time.time()
gbm0 = GradientBoostingClassifier(random_state=42, max_depth=1)
gbm0.fit(points_train, y_train)
finish = time.time()
print("Time：%f s" %(finish-start))
pred = gbm0.predict(points_test)
print("Baseline GBM Accuracy : %.4g" % metrics.accuracy_score(y_test, pred))
# Out:
# Time：500.429408 s
# Baseline GBM Accuracy : 0.446

# %% [markdown]
# The default setting of GBM model gives accuracy 44.6%, next I'll tune the model in the following order: n_estimators, min_samples_leaf, subsample, learning_rate.

# %% [markdown]
# #### Tuning Process

# %%
param_test1 = {'n_estimators':range(100,301,10)}
gsearch1 = GridSearchCV(estimator = GradientBoostingClassifier(learning_rate=0.1, min_samples_split=500, min_samples_leaf=50,max_features='sqrt',subsample=0.8,max_depth=1,random_state=42), 
                        param_grid = param_test1, scoring='accuracy',n_jobs=4,iid=False, cv=5)
gsearch1.fit(np.array(points_train), np.array(y_train))
gsearch1.best_estimator_, gsearch1.best_params_, gsearch1.best_score_
# Out:
# (GradientBoostingClassifier(criterion='friedman_mse', init=None,
#                             learning_rate=0.1, loss='deviance', max_depth=1,
#                             max_features='sqrt', max_leaf_nodes=None,
#                             min_impurity_decrease=0.0, min_impurity_split=None,
#                             min_samples_leaf=50, min_samples_split=500,
#                             min_weight_fraction_leaf=0.0, n_estimators=230,
#                             n_iter_no_change=None, presort='auto',
#                             random_state=42, subsample=0.8, tol=0.0001,
#                             validation_fraction=0.1, verbose=0,
#                             warm_start=False),
#  {'n_estimators': 230},
#  0.45619765122118566)

# %%
param_test2 = {'min_samples_leaf':range(30,101,10)}
gsearch2 = GridSearchCV(estimator = GradientBoostingClassifier(learning_rate=0.1, n_estimators=230, max_depth=1,max_features='sqrt', subsample=0.8, random_state=42), 
                        param_grid = param_test2, scoring='accuracy',n_jobs=4,iid=False, cv=5)
gsearch2.fit(points_train, y_train)
gsearch2.best_estimator_, gsearch2.best_params_, gsearch2.best_score_
# Out:
# (GradientBoostingClassifier(criterion='friedman_mse', init=None,
#                             learning_rate=0.1, loss='deviance', max_depth=1,
#                             max_features='sqrt', max_leaf_nodes=None,
#                             min_impurity_decrease=0.0, min_impurity_split=None,
#                             min_samples_leaf=90, min_samples_split=2,
#                             min_weight_fraction_leaf=0.0, n_estimators=230,
#                             n_iter_no_change=None, presort='auto',
#                             random_state=42, subsample=0.8, tol=0.0001,
#                             validation_fraction=0.1, verbose=0,
#                             warm_start=False),
#  {'min_samples_leaf': 90},
#  0.4602770254674405)

# %% [markdown]
# After cross validating, the GBM model we choose will be
# learning_rate=0.01, n_estimators=900, max_depth=1,min_samples_leaf=90, subsample=0.85

# %% [markdown]
# #### Prediction

# %%
gbm_trained = GradientBoostingClassifier(
    random_state=42, 
    learning_rate=0.1, 
    n_estimators=230, 
    max_depth=1, 
    min_samples_leaf=90, 
    subsample=0.85)
gbm_trained.fit(points_train, y_train)
start = time.time()
pred = gbm_trained.predict(points_train)
finish = time.time()
print("Time：%f s" %(finish-start))
print("GBM Accuracy on training data: %.4g" % metrics.accuracy_score(y_train, pred))

start = time.time()
pred = gbm_trained.predict(points_test)
finish = time.time()
print("Time：%f s" %(finish-start))
print("GBM Accuracy on test data: %.4g" % metrics.accuracy_score(y_test, pred))
# Out:
# Time：0.173605 s
# GBM Accuracy on training data: 0.965
# Time：0.031174 s
# GBM Accuracy on test data: 0.468

# %%
start = time.time()
gbm_trained = GradientBoostingClassifier(
    random_state=42, 
    learning_rate=0.1, 
    n_estimators=230, 
    max_depth=1, 
    min_samples_leaf=90, 
    subsample=0.85)
gbm_trained.fit(pair_dist, y)
finish = time.time()
print("Time：%f s" %(finish-start))
# Out:
# Time：1165.229694 s

# %%
from sklearn.externals import joblib
joblib.dump(gbm_trained, "gbm_trained.m")
# Out:
# ['gbm_trained.m']

# %% [markdown]
# ## SVM & CV

# %%
########## Scaling datasets ##########
points_train_np = np.array(points_train)
points_test_np = np.array(points_test)
y_train_np = np.array(y_train)
y_test_np = np.array(y_test)
points_train_scale = scale(points_train_np)
points_test_scale = scale(points_test_np)

# %%
########## PCA Modules ###########

#n_comp = 1000
#pca = PCA(n_components=n_comp, svd_solver='randomized',
#          whiten=True).fit(points_train_np)
#points_train_pca = pca.transform(points_train_np)
#points_test_pca = pca.transform(points_test_np)

# %% [markdown]
# #### Tuning Process

# %%
###### Tunning Modules #########
tunning = False
t0 = time.time()

if tunning:
  param_grid = {'C': [1,5,10],
              'gamma': [0.00001,0.0001,0.01], }
  clf = GridSearchCV(SVC(kernel='rbf', class_weight='balanced'),
                   param_grid, cv=5, iid=False)
  clf = clf.fit(points_train_scale, y_train)
  print("done in %0.3fs" % (time.time() - t0))
  print("Best estimator found by grid search:")
  print(clf.best_estimator_)

# %% [markdown]
# #### Training Model

# %%
########## Training Modules ##########
###### if tunning is true, there is no need to train the model again ########
t0 = time.time()
clf = SVC(kernel="rbf", class_weight="balanced",C=10,gamma=0.0001)
clf = clf.fit(points_train_scale, y_train)
print("Training done in %0.3fs" %(time.time() -t0))
# Out:
# Training done in 16.100s

# %% [markdown]
# #### Prediction

# %%
######## Prediction on test_set #########
t0 = time.time()
y_pred = clf.predict(points_test_scale)
acc_pred = np.sum(y_pred == y_test)/y_test.shape[0]
print("Prediction on test_set done in %0.3fs" % (time.time() - t0))
print("Test_set accurarcy is %0.3f" %acc_pred)
# Out:
# Prediction on test_set done in 5.152s
# Test_set accurarcy is 0.512

# %%
######## Prediction on train_set #########
t0 = time.time()
y_pred_train = clf.predict(points_train_scale)
acc_pred_train = np.sum(y_pred_train == y_train)/y_train.shape[0]
print("Prediction on train_set done in %0.3fs" % (time.time() - t0))
print("Train_set accurarcy is %0.3f" %acc_pred_train)
# Out:
# Prediction on train_set done in 20.572s
# Train_set accurarcy is 0.821

# %% [markdown]
# #### Train on 2500 Images

# %%
########### Using 2500 images as train_set ##########
pair_dist_scale = scale(pair_dist)
t0 = time.time()
clf = SVC(kernel="rbf", class_weight="balanced",C=10,gamma=0.0001)
clf = clf.fit(pair_dist_scale, y)
print("Training on 2500 images takes %0.3fs" %(time.time() -t0))
# Out:
# Training on 2500 images takes 23.467s

# %%
t0 = time.time()
y_pred_train_2500 = clf.predict(pair_dist_scale)
acc_pred_train_2500 = np.sum(y_pred_train_2500 == y)/y.shape[0]
print("Prediction on 2500 images takes %0.3fs" % (time.time() - t0))
print("Training accurarcy is %0.3f" %acc_pred_train_2500)
# Out:
# Prediction on 2500 images takes 32.248s
# Training accurarcy is 0.798

# %%
joblib.dump(clf, "svm_final.m")
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)
# ['svm_final.m']

# %% [markdown]
# ## Xgboost & CV

# %%
import xgboost as xgb
from sklearn.model_selection import GridSearchCV
from xgboost.sklearn import XGBClassifier
import time
import numpy as np

# %%
def modelfit(alg, dtrain, predictors, cv_folds=10):
  #Fit the algorithm on the data
  alg.fit(dtrain, predictors)

  #Predict training set:
  dtrain_predictions = alg.predict(dtrain)
  dtrain_predprob = alg.predict_proba(dtrain)[:,1]

  #Print model report:
  print("\nModel Report")
  print("Accuracy : %.4g" % metrics.accuracy_score(predictors, dtrain_predictions))

# %%
start = time.time()
xgb1 = XGBClassifier(
 objective= 'multi:softmax',
 num_class= 23,
 seed=27)

modelfit(xgb1, np.array(points_train), np.array(y_train))
finish = time.time()
print("Prediction on train_set done in %0.3fs" % (finish-start))
# Out:
# Model Report
# Accuracy : 1
# Prediction on train_set done in 782.057s

# %%
start = time.time()
preds = xgb1.predict(points_test)
acc_pred = metrics.accuracy_score(preds, y_test)
finish = time.time()
print("Prediction on test_set done in %0.3fs" % (finish - start))
print("Test_set accurarcy is %0.3f" %acc_pred)
# Out:
# Prediction on test_set done in 0.492s
# Test_set accurarcy is 0.482

# %% [markdown]
# We can see that before we change any paramters, the accuracy rate of xgboost is 48.2%,which is better than our baseline. The speed is better as well. Hence, we think we can consider this method.

# %% [markdown]
# #### Tuning Process

# %% [markdown]
# As it takes a lot of time to fit the model, we only tune the most important parameters.
#
# As I tried to change many parameters  in the model, I found 'n_estimators' and 'min_child_weight' influenced the performance  a lot.

# %% [markdown]
# Step1: n_estimators

# %%
start = time.time()
xgb2 = XGBClassifier(
 n_estimators = 1000, 
 objective= 'multi:softmax',
 num_class= 23,
 max_depth =5,
 min_child_weight =1,
 nthread =4,
 subsample = 0.8,
 colsample_bytree  = 0.8,
 scale_pos_weight = 1,
 seed=27)

modelfit(xgb2, np.array(points_train), np.array(y_train))
finish = time.time()
print("Time：%f s" %(finish-start))
print("Test_set accurarcy is %0.3f" %acc_pred)
# Out:
# Model Report
# Accuracy : 1
# Time：800.118329 s

# %%
start = time.time()
preds = xgb2.predict(points_test)
acc_pred = metrics.accuracy_score(preds, y_test)
finish = time.time()
print("Prediction on test_set done in %0.3fs" % (finish - start))
print("Test_set accurarcy is %0.3f" %acc_pred)
# Out:
# Prediction on test_set done in 0.634s
# Test_set accurarcy is 0.528

# %% [markdown]
# We changed n_estimators to 1000. Then the accuracy rate of the model increased a lot and the running time did not increase much. Hence, we tuned n_estimators to 1000. And we tuned 'subsample' and 'colsample_bytree' to a more reasonable value.

# %% [markdown]
# Step2: Tune min_child_weight

# %%
param_test1 = {
 'min_child_weight':range(1,6,2)
}
gsearch1 = GridSearchCV(estimator = XGBClassifier(n_estimators = 1000, 
 objective= 'multi:softmax',
 num_class= 23,
 max_depth =5,
 min_child_weight =1,
 nthread =4,
 subsample = 0.8,
 colsample_bytree  = 0.8,
 scale_pos_weight = 1,                                               
 seed=27), 
param_grid = param_test1, scoring = 'accuracy',iid=False, cv=2)
gsearch1.fit(np.array(points_train), np.array(y_train))
gsearch1.best_params_, gsearch1.best_score_, gsearch1.cv_results_
# Out:
# ({'min_child_weight': 1},
#  0.45233928421423175,
#  {'mean_fit_time': array([302.53986263, 267.62051725, 259.8642416 ]),
#   'mean_score_time': array([0.34943461, 0.34187734, 0.33939075]),
#   'mean_test_score': array([0.45233928, 0.44191391, 0.444447  ]),
#   'param_min_child_weight': masked_array(data=[1, 3, 5],
#                mask=[False, False, False],
#          fill_value='?',
#               dtype=object),
#   'params': [{'min_child_weight': 1},
#    {'min_child_weight': 3},
#    {'min_child_weight': 5}],
#   'rank_test_score': array([1, 3, 2], dtype=int32),
#   'split0_test_score': array([0.47912525, 0.45626243, 0.45328032]),
#   'split1_test_score': array([0.42555332, 0.42756539, 0.43561368]),
#   'std_fit_time': array([2.66214442, 4.87970066, 2.17809272]),
#   'std_score_time': array([0.00725555, 0.01867068, 0.00683665]),
#   'std_test_score': array([0.02678596, 0.01434852, 0.00883332])})

# %% [markdown]
# We found that 'min_child_weight' = 1 is the best. And we get our final xgboost model.

# %% [markdown]
# #### Training Model

# %%
start = time.time()
xgb_final = XGBClassifier(
 n_estimators = 1000, 
 objective= 'multi:softmax',
 num_class= 23,
 max_depth =5,
 min_child_weight =1,
 nthread =4,
 subsample = 0.8,
 colsample_bytree  = 0.8,
 scale_pos_weight = 1,
 seed=27)

modelfit(xgb_final, np.array(points_train), np.array(y_train))
finish = time.time()
print("Time：%f s" %(finish-start))
# Out:
# Model Report
# Accuracy : 1
# Time：807.873069 s

# %% [markdown]
# #### Prediction

# %%
start = time.time()
preds = xgb_final.predict(points_test)
acc_pred = metrics.accuracy_score(preds, y_test)
finish = time.time()
print("Prediction on test_set done in %0.3fs" % (finish - start))
print("Test_set accurarcy is %0.3f" %acc_pred)
# Out:
# Prediction on test_set done in 0.629s
# Test_set accurarcy is 0.528

# %%
start = time.time()
modelfit(xgb_final, np.array(pair_dist), np.array(y))
finish = time.time()
print("Time：%f s" %(finish-start))
# Out:
# Model Report
# Accuracy : 1
# Time：1133.331869 s

# %%
joblib.dump(xgb_final, "xgb_final.m")

# %% [markdown]
# # Step 5: Run test on test images

# %%
## zip
download = drive.CreateFile({'id': '1I8sqauDEV_iNB--2_xu7ChAsVdPXjepa'}) #please replace the id of your file
download.GetContentFile('test_set_sec1.zip')
# !unzip test_set_sec1.zip
# Out:
# Archive:  test_set_sec1.zip
#    creating: test_set_sec1/
#   inflating: __MACOSX/._test_set_sec1
#   inflating: test_set_sec1/labels_prediction.csv
#   inflating: __MACOSX/test_set_sec1/._labels_prediction.csv
#   inflating: test_set_sec1/.DS_Store
#   inflating: __MACOSX/test_set_sec1/._.DS_Store
#    creating: test_set_sec1/images/
#   inflating: __MACOSX/test_set_sec1/._images
#    creating: test_set_sec1/points/
#   inflating: __MACOSX/test_set_sec1/._points
#   inflating: test_set_sec1/images/0071.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0071.jpg
#   inflating: test_set_sec1/images/2100.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2100.jpg
#   inflating: test_set_sec1/images/0717.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0717.jpg
#   inflating: test_set_sec1/images/1409.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1409.jpg
#   inflating: test_set_sec1/images/0703.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0703.jpg
#   inflating: test_set_sec1/images/2114.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2114.jpg
#   inflating: test_set_sec1/images/0065.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0065.jpg
#   inflating: test_set_sec1/images/1353.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1353.jpg
#   inflating: test_set_sec1/images/1435.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1435.jpg
#   inflating: test_set_sec1/images/2128.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2128.jpg
#   inflating: test_set_sec1/images/1421.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1421.jpg
#   inflating: test_set_sec1/images/1347.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1347.jpg
#   inflating: test_set_sec1/images/0059.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0059.jpg
#   inflating: test_set_sec1/images/0918.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0918.jpg
#   inflating: test_set_sec1/images/1390.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1390.jpg
#   inflating: test_set_sec1/images/0930.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0930.jpg
#   inflating: test_set_sec1/images/0924.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0924.jpg
#   inflating: test_set_sec1/images/1384.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1384.jpg
#   inflating: test_set_sec1/images/0515.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0515.jpg
#   inflating: test_set_sec1/images/2302.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2302.jpg
#   inflating: test_set_sec1/images/2464.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2464.jpg
#   inflating: test_set_sec1/images/0273.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0273.jpg
#   inflating: test_set_sec1/images/0267.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0267.jpg
#   inflating: test_set_sec1/images/1179.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1179.jpg
#   inflating: test_set_sec1/images/2470.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2470.jpg
#   inflating: test_set_sec1/images/2316.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2316.jpg
#   inflating: test_set_sec1/images/0501.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0501.jpg
#   inflating: test_set_sec1/images/1637.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1637.jpg
#   inflating: test_set_sec1/images/0529.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0529.jpg
#   inflating: test_set_sec1/images/1151.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1151.jpg
#   inflating: test_set_sec1/images/2458.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2458.jpg
#   inflating: test_set_sec1/images/1145.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1145.jpg
#   inflating: test_set_sec1/images/1623.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1623.jpg
#   inflating: test_set_sec1/images/1810.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1810.jpg
#   inflating: test_set_sec1/images/1804.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1804.jpg
#   inflating: test_set_sec1/images/1192.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1192.jpg
#   inflating: test_set_sec1/images/1186.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1186.jpg
#   inflating: test_set_sec1/images/0298.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0298.jpg
#   inflating: test_set_sec1/images/1838.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1838.jpg
#   inflating: test_set_sec1/images/0461.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0461.jpg
#   inflating: test_set_sec1/images/2276.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2276.jpg
#   inflating: test_set_sec1/images/1019.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1019.jpg
#   inflating: test_set_sec1/images/0307.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0307.jpg
#   inflating: test_set_sec1/images/0313.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0313.jpg
#   inflating: test_set_sec1/images/2262.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2262.jpg
#   inflating: test_set_sec1/images/0475.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0475.jpg
#   inflating: test_set_sec1/images/1743.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1743.jpg
#   inflating: test_set_sec1/images/1025.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1025.jpg
#   inflating: test_set_sec1/images/1031.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1031.jpg
#   inflating: test_set_sec1/images/0449.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0449.jpg
#   inflating: test_set_sec1/images/1757.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1757.jpg
#   inflating: test_set_sec1/images/1964.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1964.jpg
#   inflating: test_set_sec1/images/1970.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1970.jpg
#   inflating: test_set_sec1/images/1780.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1780.jpg
#   inflating: test_set_sec1/images/1958.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1958.jpg
#   inflating: test_set_sec1/images/2289.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2289.jpg
#   inflating: test_set_sec1/images/1794.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1794.jpg
#   inflating: test_set_sec1/images/0105.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0105.jpg
#   inflating: test_set_sec1/images/2074.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2074.jpg
#   inflating: test_set_sec1/images/0663.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0663.jpg
#   inflating: test_set_sec1/images/1569.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1569.jpg
#   inflating: test_set_sec1/images/0677.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0677.jpg
#   inflating: test_set_sec1/images/2060.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2060.jpg
#   inflating: test_set_sec1/images/0111.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0111.jpg
#   inflating: test_set_sec1/images/0139.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0139.jpg
#   inflating: test_set_sec1/images/1227.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1227.jpg
#   inflating: test_set_sec1/images/0887.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0887.jpg
#   inflating: test_set_sec1/images/1541.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1541.jpg
#   inflating: test_set_sec1/images/2048.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2048.jpg
#   inflating: test_set_sec1/images/0893.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0893.jpg
#   inflating: test_set_sec1/images/1555.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1555.jpg
#   inflating: test_set_sec1/images/1233.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1233.jpg
#   inflating: test_set_sec1/images/0878.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0878.jpg
#   inflating: test_set_sec1/images/0844.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0844.jpg
#   inflating: test_set_sec1/images/1582.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1582.jpg
#   inflating: test_set_sec1/images/0688.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0688.jpg
#   inflating: test_set_sec1/images/0850.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0850.jpg
#   inflating: test_set_sec1/images/1596.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1596.jpg
#   inflating: test_set_sec1/images/1597.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1597.jpg
#   inflating: test_set_sec1/images/0851.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0851.jpg
#   inflating: test_set_sec1/images/0689.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0689.jpg
#   inflating: test_set_sec1/images/1583.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1583.jpg
#   inflating: test_set_sec1/images/0845.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0845.jpg
#   inflating: test_set_sec1/images/0879.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0879.jpg
#   inflating: test_set_sec1/images/1554.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1554.jpg
#   inflating: test_set_sec1/images/0892.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0892.jpg
#   inflating: test_set_sec1/images/1232.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1232.jpg
#   inflating: test_set_sec1/images/1226.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1226.jpg
#   inflating: test_set_sec1/images/0138.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0138.jpg
#   inflating: test_set_sec1/images/2049.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2049.jpg
#   inflating: test_set_sec1/images/1540.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1540.jpg
#   inflating: test_set_sec1/images/0886.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0886.jpg
#   inflating: test_set_sec1/images/2061.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2061.jpg
#   inflating: test_set_sec1/images/0676.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0676.jpg
#   inflating: test_set_sec1/images/1568.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1568.jpg
#   inflating: test_set_sec1/images/0110.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0110.jpg
#   inflating: test_set_sec1/images/0104.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0104.jpg
#   inflating: test_set_sec1/images/0662.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0662.jpg
#   inflating: test_set_sec1/images/2075.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2075.jpg
#   inflating: test_set_sec1/images/1795.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1795.jpg
#   inflating: test_set_sec1/images/2288.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2288.jpg
#   inflating: test_set_sec1/images/1959.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1959.jpg
#   inflating: test_set_sec1/images/1781.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1781.jpg
#   inflating: test_set_sec1/images/1971.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1971.jpg
#   inflating: test_set_sec1/images/1965.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1965.jpg
#   inflating: test_set_sec1/images/1030.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1030.jpg
#   inflating: test_set_sec1/images/1756.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1756.jpg
#   inflating: test_set_sec1/images/0448.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0448.jpg
#   inflating: test_set_sec1/images/1742.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1742.jpg
#   inflating: test_set_sec1/images/1024.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1024.jpg
#   inflating: test_set_sec1/images/0312.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0312.jpg
#   inflating: test_set_sec1/images/0474.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0474.jpg
#   inflating: test_set_sec1/images/2263.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2263.jpg
#   inflating: test_set_sec1/images/2277.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2277.jpg
#   inflating: test_set_sec1/images/0460.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0460.jpg
#   inflating: test_set_sec1/images/0306.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0306.jpg
#   inflating: test_set_sec1/images/1018.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1018.jpg
#   inflating: test_set_sec1/images/0299.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0299.jpg
#   inflating: test_set_sec1/images/1187.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1187.jpg
#   inflating: test_set_sec1/images/1839.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1839.jpg
#   inflating: test_set_sec1/images/1193.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1193.jpg
#   inflating: test_set_sec1/images/1805.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1805.jpg
#   inflating: test_set_sec1/images/1811.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1811.jpg
#   inflating: test_set_sec1/images/1144.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1144.jpg
#   inflating: test_set_sec1/images/1622.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1622.jpg
#   inflating: test_set_sec1/images/0528.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0528.jpg
#   inflating: test_set_sec1/images/1636.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1636.jpg
#   inflating: test_set_sec1/images/2459.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2459.jpg
#   inflating: test_set_sec1/images/1150.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1150.jpg
#   inflating: test_set_sec1/images/2471.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2471.jpg
#   inflating: test_set_sec1/images/1178.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1178.jpg
#   inflating: test_set_sec1/images/0266.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0266.jpg
#   inflating: test_set_sec1/images/0500.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0500.jpg
#   inflating: test_set_sec1/images/2317.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2317.jpg
#   inflating: test_set_sec1/images/2303.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2303.jpg
#   inflating: test_set_sec1/images/0514.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0514.jpg
#   inflating: test_set_sec1/images/0272.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0272.jpg
#   inflating: test_set_sec1/images/2465.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2465.jpg
#   inflating: test_set_sec1/images/0925.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0925.jpg
#   inflating: test_set_sec1/images/1385.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1385.jpg
#   inflating: test_set_sec1/images/1391.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1391.jpg
#   inflating: test_set_sec1/images/0931.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0931.jpg
#   inflating: test_set_sec1/images/0919.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0919.jpg
#   inflating: test_set_sec1/images/1420.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1420.jpg
#   inflating: test_set_sec1/images/2129.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2129.jpg
#   inflating: test_set_sec1/images/0058.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0058.jpg
#   inflating: test_set_sec1/images/1346.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1346.jpg
#   inflating: test_set_sec1/images/1352.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1352.jpg
#   inflating: test_set_sec1/images/1434.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1434.jpg
#   inflating: test_set_sec1/images/2115.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2115.jpg
#   inflating: test_set_sec1/images/0702.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0702.jpg
#   inflating: test_set_sec1/images/0064.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0064.jpg
#   inflating: test_set_sec1/images/0070.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0070.jpg
#   inflating: test_set_sec1/images/1408.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1408.jpg
#   inflating: test_set_sec1/images/0716.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0716.jpg
#   inflating: test_set_sec1/images/2101.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2101.jpg
#   inflating: test_set_sec1/images/1378.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1378.jpg
#   inflating: test_set_sec1/images/0066.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0066.jpg
#   inflating: test_set_sec1/images/0700.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0700.jpg
#   inflating: test_set_sec1/images/2117.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2117.jpg
#   inflating: test_set_sec1/images/2103.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2103.jpg
#   inflating: test_set_sec1/images/0714.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0714.jpg
#   inflating: test_set_sec1/images/0072.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0072.jpg
#   inflating: test_set_sec1/images/1344.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1344.jpg
#   inflating: test_set_sec1/images/1422.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1422.jpg
#   inflating: test_set_sec1/images/0728.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0728.jpg
#   inflating: test_set_sec1/images/1436.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1436.jpg
#   inflating: test_set_sec1/images/1350.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1350.jpg
#   inflating: test_set_sec1/images/0099.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0099.jpg
#   inflating: test_set_sec1/images/1387.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1387.jpg
#   inflating: test_set_sec1/images/0927.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0927.jpg
#   inflating: test_set_sec1/images/0933.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0933.jpg
#   inflating: test_set_sec1/images/1393.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1393.jpg
#   inflating: test_set_sec1/images/2315.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2315.jpg
#   inflating: test_set_sec1/images/0502.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0502.jpg
#   inflating: test_set_sec1/images/0264.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0264.jpg
#   inflating: test_set_sec1/images/2473.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2473.jpg
#   inflating: test_set_sec1/images/2467.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2467.jpg
#   inflating: test_set_sec1/images/0270.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0270.jpg
#   inflating: test_set_sec1/images/1608.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1608.jpg
#   inflating: test_set_sec1/images/0516.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0516.jpg
#   inflating: test_set_sec1/images/2301.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2301.jpg
#   inflating: test_set_sec1/images/1620.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1620.jpg
#   inflating: test_set_sec1/images/2329.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2329.jpg
#   inflating: test_set_sec1/images/0258.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0258.jpg
#   inflating: test_set_sec1/images/1146.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1146.jpg
#   inflating: test_set_sec1/images/1152.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1152.jpg
#   inflating: test_set_sec1/images/1634.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1634.jpg
#   inflating: test_set_sec1/images/1807.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1807.jpg
#   inflating: test_set_sec1/images/1813.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1813.jpg
#   inflating: test_set_sec1/images/1185.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1185.jpg
#   inflating: test_set_sec1/images/2498.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2498.jpg
#   inflating: test_set_sec1/images/1191.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1191.jpg
#   inflating: test_set_sec1/images/2261.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2261.jpg
#   inflating: test_set_sec1/images/0476.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0476.jpg
#   inflating: test_set_sec1/images/1768.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1768.jpg
#   inflating: test_set_sec1/images/0310.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0310.jpg
#   inflating: test_set_sec1/images/0304.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0304.jpg
#   inflating: test_set_sec1/images/0462.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0462.jpg
#   inflating: test_set_sec1/images/2275.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2275.jpg
#   inflating: test_set_sec1/images/1754.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1754.jpg
#   inflating: test_set_sec1/images/1032.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1032.jpg
#   inflating: test_set_sec1/images/1026.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1026.jpg
#   inflating: test_set_sec1/images/0338.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0338.jpg
#   inflating: test_set_sec1/images/2249.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2249.jpg
#   inflating: test_set_sec1/images/1998.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1998.jpg
#   inflating: test_set_sec1/images/1740.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1740.jpg
#   inflating: test_set_sec1/images/1973.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1973.jpg
#   inflating: test_set_sec1/images/1967.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1967.jpg
#   inflating: test_set_sec1/images/1797.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1797.jpg
#   inflating: test_set_sec1/images/0489.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0489.jpg
#   inflating: test_set_sec1/images/1783.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1783.jpg
#   inflating: test_set_sec1/images/0112.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0112.jpg
#   inflating: test_set_sec1/images/0674.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0674.jpg
#   inflating: test_set_sec1/images/2063.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2063.jpg
#   inflating: test_set_sec1/images/2077.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2077.jpg
#   inflating: test_set_sec1/images/0660.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0660.jpg
#   inflating: test_set_sec1/images/0106.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0106.jpg
#   inflating: test_set_sec1/images/1218.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1218.jpg
#   inflating: test_set_sec1/images/1230.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1230.jpg
#   inflating: test_set_sec1/images/0890.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0890.jpg
#   inflating: test_set_sec1/images/1556.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1556.jpg
#   inflating: test_set_sec1/images/0648.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0648.jpg
#   inflating: test_set_sec1/images/0884.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0884.jpg
#   inflating: test_set_sec1/images/1542.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1542.jpg
#   inflating: test_set_sec1/images/1224.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1224.jpg
#   inflating: test_set_sec1/images/0853.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0853.jpg
#   inflating: test_set_sec1/images/1595.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1595.jpg
#   inflating: test_set_sec1/images/2088.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2088.jpg
#   inflating: test_set_sec1/images/0847.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0847.jpg
#   inflating: test_set_sec1/images/1581.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1581.jpg
#   inflating: test_set_sec1/images/1580.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1580.jpg
#   inflating: test_set_sec1/images/0846.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0846.jpg
#   inflating: test_set_sec1/images/2089.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2089.jpg
#   inflating: test_set_sec1/images/1594.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1594.jpg
#   inflating: test_set_sec1/images/0852.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0852.jpg
#   inflating: test_set_sec1/images/1543.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1543.jpg
#   inflating: test_set_sec1/images/0885.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0885.jpg
#   inflating: test_set_sec1/images/1225.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1225.jpg
#   inflating: test_set_sec1/images/1231.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1231.jpg
#   inflating: test_set_sec1/images/0649.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0649.jpg
#   inflating: test_set_sec1/images/1557.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1557.jpg
#   inflating: test_set_sec1/images/0891.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0891.jpg
#   inflating: test_set_sec1/images/0661.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0661.jpg
#   inflating: test_set_sec1/images/2076.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2076.jpg
#   inflating: test_set_sec1/images/1219.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1219.jpg
#   inflating: test_set_sec1/images/0107.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0107.jpg
#   inflating: test_set_sec1/images/0113.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0113.jpg
#   inflating: test_set_sec1/images/2062.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2062.jpg
#   inflating: test_set_sec1/images/0675.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0675.jpg
#   inflating: test_set_sec1/images/1782.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1782.jpg
#   inflating: test_set_sec1/images/0488.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0488.jpg
#   inflating: test_set_sec1/images/1796.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1796.jpg
#   inflating: test_set_sec1/images/1966.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1966.jpg
#   inflating: test_set_sec1/images/1972.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1972.jpg
#   inflating: test_set_sec1/images/0339.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0339.jpg
#   inflating: test_set_sec1/images/1027.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1027.jpg
#   inflating: test_set_sec1/images/1741.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1741.jpg
#   inflating: test_set_sec1/images/1999.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1999.jpg
#   inflating: test_set_sec1/images/2248.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2248.jpg
#   inflating: test_set_sec1/images/1755.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1755.jpg
#   inflating: test_set_sec1/images/1033.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1033.jpg
#   inflating: test_set_sec1/images/0305.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0305.jpg
#   inflating: test_set_sec1/images/2274.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2274.jpg
#   inflating: test_set_sec1/images/0463.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0463.jpg
#   inflating: test_set_sec1/images/1769.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1769.jpg
#   inflating: test_set_sec1/images/0477.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0477.jpg
#   inflating: test_set_sec1/images/2260.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2260.jpg
#   inflating: test_set_sec1/images/0311.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0311.jpg
#   inflating: test_set_sec1/images/1190.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1190.jpg
#   inflating: test_set_sec1/images/2499.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2499.jpg
#   inflating: test_set_sec1/images/1184.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1184.jpg
#   inflating: test_set_sec1/images/1812.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1812.jpg
#   inflating: test_set_sec1/images/1806.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1806.jpg
#   inflating: test_set_sec1/images/1153.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1153.jpg
#   inflating: test_set_sec1/images/1635.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1635.jpg
#   inflating: test_set_sec1/images/2328.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2328.jpg
#   inflating: test_set_sec1/images/1621.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1621.jpg
#   inflating: test_set_sec1/images/1147.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1147.jpg
#   inflating: test_set_sec1/images/0259.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0259.jpg
#   inflating: test_set_sec1/images/0271.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0271.jpg
#   inflating: test_set_sec1/images/2466.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2466.jpg
#   inflating: test_set_sec1/images/2300.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2300.jpg
#   inflating: test_set_sec1/images/0517.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0517.jpg
#   inflating: test_set_sec1/images/1609.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1609.jpg
#   inflating: test_set_sec1/images/0503.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0503.jpg
#   inflating: test_set_sec1/images/2314.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2314.jpg
#   inflating: test_set_sec1/images/2472.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2472.jpg
#   inflating: test_set_sec1/images/0265.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0265.jpg
#   inflating: test_set_sec1/images/0932.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0932.jpg
#   inflating: test_set_sec1/images/1392.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1392.jpg
#   inflating: test_set_sec1/images/1386.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1386.jpg
#   inflating: test_set_sec1/images/0098.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0098.jpg
#   inflating: test_set_sec1/images/0926.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0926.jpg
#   inflating: test_set_sec1/images/1437.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1437.jpg
#   inflating: test_set_sec1/images/0729.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0729.jpg
#   inflating: test_set_sec1/images/1351.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1351.jpg
#   inflating: test_set_sec1/images/1345.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1345.jpg
#   inflating: test_set_sec1/images/1423.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1423.jpg
#   inflating: test_set_sec1/images/0715.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0715.jpg
#   inflating: test_set_sec1/images/2102.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2102.jpg
#   inflating: test_set_sec1/images/0073.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0073.jpg
#   inflating: test_set_sec1/images/0067.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0067.jpg
#   inflating: test_set_sec1/images/1379.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1379.jpg
#   inflating: test_set_sec1/images/2116.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2116.jpg
#   inflating: test_set_sec1/images/0701.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0701.jpg
#   inflating: test_set_sec1/images/0739.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0739.jpg
#   inflating: test_set_sec1/images/1427.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1427.jpg
#   inflating: test_set_sec1/images/1341.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1341.jpg
#   inflating: test_set_sec1/images/1355.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1355.jpg
#   inflating: test_set_sec1/images/1433.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1433.jpg
#   inflating: test_set_sec1/images/0705.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0705.jpg
#   inflating: test_set_sec1/images/2112.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2112.jpg
#   inflating: test_set_sec1/images/0063.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0063.jpg
#   inflating: test_set_sec1/images/1369.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1369.jpg
#   inflating: test_set_sec1/images/0077.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0077.jpg
#   inflating: test_set_sec1/images/2106.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2106.jpg
#   inflating: test_set_sec1/images/0711.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0711.jpg
#   inflating: test_set_sec1/images/0922.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0922.jpg
#   inflating: test_set_sec1/images/1382.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1382.jpg
#   inflating: test_set_sec1/images/0088.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0088.jpg
#   inflating: test_set_sec1/images/1396.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1396.jpg
#   inflating: test_set_sec1/images/0936.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0936.jpg
#   inflating: test_set_sec1/images/1143.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1143.jpg
#   inflating: test_set_sec1/images/1625.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1625.jpg
#   inflating: test_set_sec1/images/2338.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2338.jpg
#   inflating: test_set_sec1/images/1631.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1631.jpg
#   inflating: test_set_sec1/images/0249.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0249.jpg
#   inflating: test_set_sec1/images/1157.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1157.jpg
#   inflating: test_set_sec1/images/0261.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0261.jpg
#   inflating: test_set_sec1/images/2476.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2476.jpg
#   inflating: test_set_sec1/images/2310.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2310.jpg
#   inflating: test_set_sec1/images/1619.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1619.jpg
#   inflating: test_set_sec1/images/0507.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0507.jpg
#   inflating: test_set_sec1/images/0513.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0513.jpg
#   inflating: test_set_sec1/images/2304.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2304.jpg
#   inflating: test_set_sec1/images/2462.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2462.jpg
#   inflating: test_set_sec1/images/0275.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0275.jpg
#   inflating: test_set_sec1/images/1180.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1180.jpg
#   inflating: test_set_sec1/images/2489.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2489.jpg
#   inflating: test_set_sec1/images/1194.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1194.jpg
#   inflating: test_set_sec1/images/1802.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1802.jpg
#   inflating: test_set_sec1/images/1816.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1816.jpg
#   inflating: test_set_sec1/images/1037.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1037.jpg
#   inflating: test_set_sec1/images/0329.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0329.jpg
#   inflating: test_set_sec1/images/1989.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1989.jpg
#   inflating: test_set_sec1/images/1751.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1751.jpg
#   inflating: test_set_sec1/images/2258.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2258.jpg
#   inflating: test_set_sec1/images/1745.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1745.jpg
#   inflating: test_set_sec1/images/1023.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1023.jpg
#   inflating: test_set_sec1/images/0315.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0315.jpg
#   inflating: test_set_sec1/images/2264.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2264.jpg
#   inflating: test_set_sec1/images/0473.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0473.jpg
#   inflating: test_set_sec1/images/0467.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0467.jpg
#   inflating: test_set_sec1/images/1779.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1779.jpg
#   inflating: test_set_sec1/images/2270.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2270.jpg
#   inflating: test_set_sec1/images/0301.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0301.jpg
#   inflating: test_set_sec1/images/1792.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1792.jpg
#   inflating: test_set_sec1/images/1786.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1786.jpg
#   inflating: test_set_sec1/images/0498.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0498.jpg
#   inflating: test_set_sec1/images/1976.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1976.jpg
#   inflating: test_set_sec1/images/1962.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1962.jpg
#   inflating: test_set_sec1/images/1553.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1553.jpg
#   inflating: test_set_sec1/images/0895.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0895.jpg
#   inflating: test_set_sec1/images/1235.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1235.jpg
#   inflating: test_set_sec1/images/1221.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1221.jpg
#   inflating: test_set_sec1/images/1547.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1547.jpg
#   inflating: test_set_sec1/images/0881.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0881.jpg
#   inflating: test_set_sec1/images/0659.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0659.jpg
#   inflating: test_set_sec1/images/0671.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0671.jpg
#   inflating: test_set_sec1/images/2066.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2066.jpg
#   inflating: test_set_sec1/images/0117.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0117.jpg
#   inflating: test_set_sec1/images/1209.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1209.jpg
#   inflating: test_set_sec1/images/0103.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0103.jpg
#   inflating: test_set_sec1/images/2072.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2072.jpg
#   inflating: test_set_sec1/images/0665.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0665.jpg
#   inflating: test_set_sec1/images/1590.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1590.jpg
#   inflating: test_set_sec1/images/0856.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0856.jpg
#   inflating: test_set_sec1/images/2099.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2099.jpg
#   inflating: test_set_sec1/images/1584.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1584.jpg
#   inflating: test_set_sec1/images/0842.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0842.jpg
#   inflating: test_set_sec1/images/0843.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0843.jpg
#   inflating: test_set_sec1/images/1585.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1585.jpg
#   inflating: test_set_sec1/images/2098.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2098.jpg
#   inflating: test_set_sec1/images/0857.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0857.jpg
#   inflating: test_set_sec1/images/1591.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1591.jpg
#   inflating: test_set_sec1/images/0102.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0102.jpg
#   inflating: test_set_sec1/images/0664.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0664.jpg
#   inflating: test_set_sec1/images/2073.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2073.jpg
#   inflating: test_set_sec1/images/2067.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2067.jpg
#   inflating: test_set_sec1/images/0670.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0670.jpg
#   inflating: test_set_sec1/images/1208.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1208.jpg
#   inflating: test_set_sec1/images/0116.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0116.jpg
#   inflating: test_set_sec1/images/1220.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1220.jpg
#   inflating: test_set_sec1/images/0658.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0658.jpg
#   inflating: test_set_sec1/images/0880.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0880.jpg
#   inflating: test_set_sec1/images/1546.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1546.jpg
#   inflating: test_set_sec1/images/0894.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0894.jpg
#   inflating: test_set_sec1/images/1552.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1552.jpg
#   inflating: test_set_sec1/images/1234.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1234.jpg
#   inflating: test_set_sec1/images/1963.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1963.jpg
#   inflating: test_set_sec1/images/1977.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1977.jpg
#   inflating: test_set_sec1/images/0499.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0499.jpg
#   inflating: test_set_sec1/images/1787.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1787.jpg
#   inflating: test_set_sec1/images/1793.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1793.jpg
#   inflating: test_set_sec1/images/2271.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2271.jpg
#   inflating: test_set_sec1/images/1778.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1778.jpg
#   inflating: test_set_sec1/images/0466.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0466.jpg
#   inflating: test_set_sec1/images/0300.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0300.jpg
#   inflating: test_set_sec1/images/0314.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0314.jpg
#   inflating: test_set_sec1/images/0472.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0472.jpg
#   inflating: test_set_sec1/images/2265.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2265.jpg
#   inflating: test_set_sec1/images/1744.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1744.jpg
#   inflating: test_set_sec1/images/1022.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1022.jpg
#   inflating: test_set_sec1/images/0328.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0328.jpg
#   inflating: test_set_sec1/images/1036.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1036.jpg
#   inflating: test_set_sec1/images/2259.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2259.jpg
#   inflating: test_set_sec1/images/1750.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1750.jpg
#   inflating: test_set_sec1/images/1988.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1988.jpg
#   inflating: test_set_sec1/images/1817.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1817.jpg
#   inflating: test_set_sec1/images/1803.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1803.jpg
#   inflating: test_set_sec1/images/1195.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1195.jpg
#   inflating: test_set_sec1/images/2488.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2488.jpg
#   inflating: test_set_sec1/images/1181.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1181.jpg
#   inflating: test_set_sec1/images/2305.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2305.jpg
#   inflating: test_set_sec1/images/0512.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0512.jpg
#   inflating: test_set_sec1/images/0274.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0274.jpg
#   inflating: test_set_sec1/images/2463.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2463.jpg
#   inflating: test_set_sec1/images/2477.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2477.jpg
#   inflating: test_set_sec1/images/0260.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0260.jpg
#   inflating: test_set_sec1/images/0506.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0506.jpg
#   inflating: test_set_sec1/images/1618.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1618.jpg
#   inflating: test_set_sec1/images/2311.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2311.jpg
#   inflating: test_set_sec1/images/1630.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1630.jpg
#   inflating: test_set_sec1/images/2339.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2339.jpg
#   inflating: test_set_sec1/images/1156.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1156.jpg
#   inflating: test_set_sec1/images/0248.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0248.jpg
#   inflating: test_set_sec1/images/1142.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1142.jpg
#   inflating: test_set_sec1/images/1624.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1624.jpg
#   inflating: test_set_sec1/images/1397.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1397.jpg
#   inflating: test_set_sec1/images/0089.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0089.jpg
#   inflating: test_set_sec1/images/0937.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0937.jpg
#   inflating: test_set_sec1/images/0923.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0923.jpg
#   inflating: test_set_sec1/images/1383.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1383.jpg
#   inflating: test_set_sec1/images/0076.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0076.jpg
#   inflating: test_set_sec1/images/1368.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1368.jpg
#   inflating: test_set_sec1/images/0710.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0710.jpg
#   inflating: test_set_sec1/images/2107.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2107.jpg
#   inflating: test_set_sec1/images/2113.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2113.jpg
#   inflating: test_set_sec1/images/0704.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0704.jpg
#   inflating: test_set_sec1/images/0062.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0062.jpg
#   inflating: test_set_sec1/images/1354.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1354.jpg
#   inflating: test_set_sec1/images/1432.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1432.jpg
#   inflating: test_set_sec1/images/1426.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1426.jpg
#   inflating: test_set_sec1/images/0738.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0738.jpg
#   inflating: test_set_sec1/images/1340.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1340.jpg
#   inflating: test_set_sec1/images/1430.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1430.jpg
#   inflating: test_set_sec1/images/2139.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2139.jpg
#   inflating: test_set_sec1/images/1356.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1356.jpg
#   inflating: test_set_sec1/images/0048.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0048.jpg
#   inflating: test_set_sec1/images/1342.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1342.jpg
#   inflating: test_set_sec1/images/1424.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1424.jpg
#   inflating: test_set_sec1/images/2105.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2105.jpg
#   inflating: test_set_sec1/images/0712.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0712.jpg
#   inflating: test_set_sec1/images/0074.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0074.jpg
#   inflating: test_set_sec1/images/0060.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0060.jpg
#   inflating: test_set_sec1/images/0706.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0706.jpg
#   inflating: test_set_sec1/images/1418.jpg
#   inflating: __MACOSX/test_set_sec1/images/._1418.jpg
#   inflating: test_set_sec1/images/2111.jpg
#   inflating: __MACOSX/test_set_sec1/images/._2111.jpg
#   inflating: test_set_sec1/images/0935.jpg
#   inflating: __MACOSX/test_set_sec1/images/._0935.jpg
#   inflating: test_set_sec1/images/1395.jpg
# ...
#   inflating: test_set_sec1/points/0385.mat
#   inflating: __MACOSX/test_set_sec1/points/._0385.mat
#   inflating: test_set_sec1/points/1070.mat
#   inflating: __MACOSX/test_set_sec1/points/._1070.mat
#   inflating: test_set_sec1/points/0408.mat
#   inflating: __MACOSX/test_set_sec1/points/._0408.mat
#   inflating: test_set_sec1/points/1716.mat
#   inflating: __MACOSX/test_set_sec1/points/._1716.mat
#   inflating: test_set_sec1/points/1702.mat
#   inflating: __MACOSX/test_set_sec1/points/._1702.mat
#   inflating: test_set_sec1/points/1064.mat
#   inflating: __MACOSX/test_set_sec1/points/._1064.mat
#   inflating: test_set_sec1/points/0352.mat
#   inflating: __MACOSX/test_set_sec1/points/._0352.mat
#   inflating: test_set_sec1/points/2223.mat
#   inflating: __MACOSX/test_set_sec1/points/._2223.mat
#   inflating: test_set_sec1/points/0434.mat
#   inflating: __MACOSX/test_set_sec1/points/._0434.mat
#   inflating: test_set_sec1/points/0420.mat
#   inflating: __MACOSX/test_set_sec1/points/._0420.mat
#   inflating: test_set_sec1/points/2237.mat
#   inflating: __MACOSX/test_set_sec1/points/._2237.mat
#   inflating: test_set_sec1/points/1058.mat
#   inflating: __MACOSX/test_set_sec1/points/._1058.mat
#   inflating: test_set_sec1/points/0346.mat
#   inflating: __MACOSX/test_set_sec1/points/._0346.mat
#   inflating: test_set_sec1/points/0811.mat
#   inflating: __MACOSX/test_set_sec1/points/._0811.mat
#   inflating: test_set_sec1/points/0805.mat
#   inflating: __MACOSX/test_set_sec1/points/._0805.mat
#   inflating: test_set_sec1/points/0193.mat
#   inflating: __MACOSX/test_set_sec1/points/._0193.mat
#   inflating: test_set_sec1/points/1299.mat
#   inflating: __MACOSX/test_set_sec1/points/._1299.mat
#   inflating: test_set_sec1/points/0187.mat
#   inflating: __MACOSX/test_set_sec1/points/._0187.mat
#   inflating: test_set_sec1/points/0839.mat
#   inflating: __MACOSX/test_set_sec1/points/._0839.mat
#   inflating: test_set_sec1/points/1514.mat
#   inflating: __MACOSX/test_set_sec1/points/._1514.mat
#   inflating: test_set_sec1/points/1272.mat
#   inflating: __MACOSX/test_set_sec1/points/._1272.mat
#   inflating: test_set_sec1/points/0178.mat
#   inflating: __MACOSX/test_set_sec1/points/._0178.mat
#   inflating: test_set_sec1/points/1266.mat
#   inflating: __MACOSX/test_set_sec1/points/._1266.mat
#   inflating: test_set_sec1/points/1500.mat
#   inflating: __MACOSX/test_set_sec1/points/._1500.mat
#   inflating: test_set_sec1/points/2009.mat
#   inflating: __MACOSX/test_set_sec1/points/._2009.mat
#   inflating: test_set_sec1/points/1528.mat
#   inflating: __MACOSX/test_set_sec1/points/._1528.mat
#   inflating: test_set_sec1/points/0636.mat
#   inflating: __MACOSX/test_set_sec1/points/._0636.mat
#   inflating: test_set_sec1/points/2021.mat
#   inflating: __MACOSX/test_set_sec1/points/._2021.mat
#   inflating: test_set_sec1/points/0150.mat
#   inflating: __MACOSX/test_set_sec1/points/._0150.mat
#   inflating: test_set_sec1/points/0144.mat
#   inflating: __MACOSX/test_set_sec1/points/._0144.mat
#   inflating: test_set_sec1/points/2035.mat
#   inflating: __MACOSX/test_set_sec1/points/._2035.mat
#   inflating: test_set_sec1/points/0622.mat
#   inflating: __MACOSX/test_set_sec1/points/._0622.mat
#   inflating: test_set_sec1/points/0965.mat
#   inflating: __MACOSX/test_set_sec1/points/._0965.mat
#   inflating: test_set_sec1/points/0971.mat
#   inflating: __MACOSX/test_set_sec1/points/._0971.mat
#   inflating: test_set_sec1/points/2196.mat
#   inflating: __MACOSX/test_set_sec1/points/._2196.mat
#   inflating: test_set_sec1/points/0959.mat
#   inflating: __MACOSX/test_set_sec1/points/._0959.mat
#   inflating: test_set_sec1/points/0781.mat
#   inflating: __MACOSX/test_set_sec1/points/._0781.mat
#   inflating: test_set_sec1/points/0795.mat
#   inflating: __MACOSX/test_set_sec1/points/._0795.mat
#   inflating: test_set_sec1/points/2182.mat
#   inflating: __MACOSX/test_set_sec1/points/._2182.mat
#   inflating: test_set_sec1/points/2169.mat
#   inflating: __MACOSX/test_set_sec1/points/._2169.mat
#   inflating: test_set_sec1/points/1460.mat
#   inflating: __MACOSX/test_set_sec1/points/._1460.mat
#   inflating: test_set_sec1/points/1306.mat
#   inflating: __MACOSX/test_set_sec1/points/._1306.mat
#   inflating: test_set_sec1/points/0018.mat
#   inflating: __MACOSX/test_set_sec1/points/._0018.mat
#   inflating: test_set_sec1/points/1312.mat
#   inflating: __MACOSX/test_set_sec1/points/._1312.mat
#   inflating: test_set_sec1/points/1474.mat
#   inflating: __MACOSX/test_set_sec1/points/._1474.mat
#   inflating: test_set_sec1/points/0742.mat
#   inflating: __MACOSX/test_set_sec1/points/._0742.mat
#   inflating: test_set_sec1/points/2155.mat
#   inflating: __MACOSX/test_set_sec1/points/._2155.mat
#   inflating: test_set_sec1/points/0024.mat
#   inflating: __MACOSX/test_set_sec1/points/._0024.mat
#   inflating: test_set_sec1/points/0030.mat
#   inflating: __MACOSX/test_set_sec1/points/._0030.mat
#   inflating: test_set_sec1/points/2141.mat
#   inflating: __MACOSX/test_set_sec1/points/._2141.mat
#   inflating: test_set_sec1/points/0756.mat
#   inflating: __MACOSX/test_set_sec1/points/._0756.mat
#   inflating: test_set_sec1/points/1448.mat
#   inflating: __MACOSX/test_set_sec1/points/._1448.mat
#   inflating: test_set_sec1/points/1879.mat
#   inflating: __MACOSX/test_set_sec1/points/._1879.mat
#   inflating: test_set_sec1/points/0583.mat
#   inflating: __MACOSX/test_set_sec1/points/._0583.mat
#   inflating: test_set_sec1/points/1845.mat
#   inflating: __MACOSX/test_set_sec1/points/._1845.mat
#   inflating: test_set_sec1/points/2394.mat
#   inflating: __MACOSX/test_set_sec1/points/._2394.mat
#   inflating: test_set_sec1/points/2380.mat
#   inflating: __MACOSX/test_set_sec1/points/._2380.mat
#   inflating: test_set_sec1/points/0597.mat
#   inflating: __MACOSX/test_set_sec1/points/._0597.mat
#   inflating: test_set_sec1/points/1851.mat
#   inflating: __MACOSX/test_set_sec1/points/._1851.mat
#   inflating: test_set_sec1/points/1689.mat
#   inflating: __MACOSX/test_set_sec1/points/._1689.mat
#   inflating: test_set_sec1/points/1104.mat
#   inflating: __MACOSX/test_set_sec1/points/._1104.mat
#   inflating: test_set_sec1/points/1662.mat
#   inflating: __MACOSX/test_set_sec1/points/._1662.mat
#   inflating: test_set_sec1/points/1676.mat
#   inflating: __MACOSX/test_set_sec1/points/._1676.mat
#   inflating: test_set_sec1/points/0568.mat
#   inflating: __MACOSX/test_set_sec1/points/._0568.mat
#   inflating: test_set_sec1/points/1110.mat
#   inflating: __MACOSX/test_set_sec1/points/._1110.mat
#   inflating: test_set_sec1/points/2419.mat
#   inflating: __MACOSX/test_set_sec1/points/._2419.mat
#   inflating: test_set_sec1/points/0226.mat
#   inflating: __MACOSX/test_set_sec1/points/._0226.mat
#   inflating: test_set_sec1/points/1138.mat
#   inflating: __MACOSX/test_set_sec1/points/._1138.mat
#   inflating: test_set_sec1/points/2431.mat
#   inflating: __MACOSX/test_set_sec1/points/._2431.mat
#   inflating: test_set_sec1/points/2357.mat
#   inflating: __MACOSX/test_set_sec1/points/._2357.mat
#   inflating: test_set_sec1/points/0540.mat
#   inflating: __MACOSX/test_set_sec1/points/._0540.mat
#   inflating: test_set_sec1/points/1886.mat
#   inflating: __MACOSX/test_set_sec1/points/._1886.mat
#   inflating: test_set_sec1/points/0554.mat
#   inflating: __MACOSX/test_set_sec1/points/._0554.mat
#   inflating: test_set_sec1/points/1892.mat
#   inflating: __MACOSX/test_set_sec1/points/._1892.mat
#   inflating: test_set_sec1/points/2343.mat
#   inflating: __MACOSX/test_set_sec1/points/._2343.mat
#   inflating: test_set_sec1/points/2425.mat
#   inflating: __MACOSX/test_set_sec1/points/._2425.mat
#   inflating: test_set_sec1/points/0232.mat
#   inflating: __MACOSX/test_set_sec1/points/._0232.mat
#   inflating: test_set_sec1/points/2342.mat
#   inflating: __MACOSX/test_set_sec1/points/._2342.mat
#   inflating: test_set_sec1/points/1893.mat
#   inflating: __MACOSX/test_set_sec1/points/._1893.mat
#   inflating: test_set_sec1/points/0555.mat
#   inflating: __MACOSX/test_set_sec1/points/._0555.mat
#   inflating: test_set_sec1/points/0233.mat
#   inflating: __MACOSX/test_set_sec1/points/._0233.mat
#   inflating: test_set_sec1/points/2424.mat
#   inflating: __MACOSX/test_set_sec1/points/._2424.mat
#   inflating: test_set_sec1/points/2430.mat
#   inflating: __MACOSX/test_set_sec1/points/._2430.mat
#   inflating: test_set_sec1/points/1139.mat
#   inflating: __MACOSX/test_set_sec1/points/._1139.mat
#   inflating: test_set_sec1/points/0227.mat
#   inflating: __MACOSX/test_set_sec1/points/._0227.mat
#   inflating: test_set_sec1/points/1887.mat
#   inflating: __MACOSX/test_set_sec1/points/._1887.mat
#   inflating: test_set_sec1/points/0541.mat
#   inflating: __MACOSX/test_set_sec1/points/._0541.mat
#   inflating: test_set_sec1/points/2356.mat
#   inflating: __MACOSX/test_set_sec1/points/._2356.mat
#   inflating: test_set_sec1/points/0569.mat
#   inflating: __MACOSX/test_set_sec1/points/._0569.mat
#   inflating: test_set_sec1/points/1677.mat
#   inflating: __MACOSX/test_set_sec1/points/._1677.mat
#   inflating: test_set_sec1/points/2418.mat
#   inflating: __MACOSX/test_set_sec1/points/._2418.mat
#   inflating: test_set_sec1/points/1111.mat
#   inflating: __MACOSX/test_set_sec1/points/._1111.mat
#   inflating: test_set_sec1/points/1105.mat
#   inflating: __MACOSX/test_set_sec1/points/._1105.mat
#   inflating: test_set_sec1/points/1663.mat
#   inflating: __MACOSX/test_set_sec1/points/._1663.mat
#   inflating: test_set_sec1/points/1688.mat
#   inflating: __MACOSX/test_set_sec1/points/._1688.mat
#   inflating: test_set_sec1/points/1850.mat
#   inflating: __MACOSX/test_set_sec1/points/._1850.mat
#   inflating: test_set_sec1/points/0596.mat
#   inflating: __MACOSX/test_set_sec1/points/._0596.mat
#   inflating: test_set_sec1/points/2381.mat
#   inflating: __MACOSX/test_set_sec1/points/._2381.mat
#   inflating: test_set_sec1/points/2395.mat
#   inflating: __MACOSX/test_set_sec1/points/._2395.mat
#   inflating: test_set_sec1/points/1844.mat
#   inflating: __MACOSX/test_set_sec1/points/._1844.mat
#   inflating: test_set_sec1/points/0582.mat
#   inflating: __MACOSX/test_set_sec1/points/._0582.mat
#   inflating: test_set_sec1/points/1878.mat
#   inflating: __MACOSX/test_set_sec1/points/._1878.mat
#   inflating: test_set_sec1/points/0031.mat
#   inflating: __MACOSX/test_set_sec1/points/._0031.mat
#   inflating: test_set_sec1/points/1449.mat
#   inflating: __MACOSX/test_set_sec1/points/._1449.mat
#   inflating: test_set_sec1/points/0757.mat
#   inflating: __MACOSX/test_set_sec1/points/._0757.mat
#   inflating: test_set_sec1/points/2140.mat
#   inflating: __MACOSX/test_set_sec1/points/._2140.mat
#   inflating: test_set_sec1/points/2154.mat
#   inflating: __MACOSX/test_set_sec1/points/._2154.mat
#   inflating: test_set_sec1/points/0743.mat
#   inflating: __MACOSX/test_set_sec1/points/._0743.mat
#   inflating: test_set_sec1/points/0025.mat
#   inflating: __MACOSX/test_set_sec1/points/._0025.mat
#   inflating: test_set_sec1/points/1313.mat
#   inflating: __MACOSX/test_set_sec1/points/._1313.mat
#   inflating: test_set_sec1/points/1475.mat
#   inflating: __MACOSX/test_set_sec1/points/._1475.mat
#   inflating: test_set_sec1/points/1461.mat
#   inflating: __MACOSX/test_set_sec1/points/._1461.mat
#   inflating: test_set_sec1/points/2168.mat
#   inflating: __MACOSX/test_set_sec1/points/._2168.mat
#   inflating: test_set_sec1/points/0019.mat
#   inflating: __MACOSX/test_set_sec1/points/._0019.mat
#   inflating: test_set_sec1/points/1307.mat
#   inflating: __MACOSX/test_set_sec1/points/._1307.mat
#   inflating: test_set_sec1/points/2183.mat
#   inflating: __MACOSX/test_set_sec1/points/._2183.mat
#   inflating: test_set_sec1/points/0794.mat
#   inflating: __MACOSX/test_set_sec1/points/._0794.mat
#   inflating: test_set_sec1/points/0780.mat
#   inflating: __MACOSX/test_set_sec1/points/._0780.mat
#   inflating: test_set_sec1/points/0958.mat
#   inflating: __MACOSX/test_set_sec1/points/._0958.mat
#   inflating: test_set_sec1/points/2197.mat
#   inflating: __MACOSX/test_set_sec1/points/._2197.mat
#   inflating: test_set_sec1/points/0970.mat
#   inflating: __MACOSX/test_set_sec1/points/._0970.mat
#   inflating: test_set_sec1/points/0964.mat
#   inflating: __MACOSX/test_set_sec1/points/._0964.mat
#   inflating: test_set_sec1/points/0145.mat
#   inflating: __MACOSX/test_set_sec1/points/._0145.mat
#   inflating: test_set_sec1/points/0623.mat
#   inflating: __MACOSX/test_set_sec1/points/._0623.mat
#   inflating: test_set_sec1/points/2034.mat
#   inflating: __MACOSX/test_set_sec1/points/._2034.mat
#   inflating: test_set_sec1/points/2020.mat
#   inflating: __MACOSX/test_set_sec1/points/._2020.mat
#   inflating: test_set_sec1/points/0637.mat
#   inflating: __MACOSX/test_set_sec1/points/._0637.mat
#   inflating: test_set_sec1/points/1529.mat
#   inflating: __MACOSX/test_set_sec1/points/._1529.mat
#   inflating: test_set_sec1/points/0151.mat
#   inflating: __MACOSX/test_set_sec1/points/._0151.mat
#   inflating: test_set_sec1/points/1267.mat
#   inflating: __MACOSX/test_set_sec1/points/._1267.mat
#   inflating: test_set_sec1/points/0179.mat
#   inflating: __MACOSX/test_set_sec1/points/._0179.mat
#   inflating: test_set_sec1/points/2008.mat
#   inflating: __MACOSX/test_set_sec1/points/._2008.mat
#   inflating: test_set_sec1/points/1501.mat
#   inflating: __MACOSX/test_set_sec1/points/._1501.mat
#   inflating: test_set_sec1/points/1515.mat
#   inflating: __MACOSX/test_set_sec1/points/._1515.mat
#   inflating: test_set_sec1/points/1273.mat
#   inflating: __MACOSX/test_set_sec1/points/._1273.mat
#   inflating: test_set_sec1/points/0186.mat
#   inflating: __MACOSX/test_set_sec1/points/._0186.mat
#   inflating: test_set_sec1/points/1298.mat
#   inflating: __MACOSX/test_set_sec1/points/._1298.mat
#   inflating: test_set_sec1/points/0838.mat
#   inflating: __MACOSX/test_set_sec1/points/._0838.mat
#   inflating: test_set_sec1/points/0192.mat
#   inflating: __MACOSX/test_set_sec1/points/._0192.mat
#   inflating: test_set_sec1/points/0804.mat
#   inflating: __MACOSX/test_set_sec1/points/._0804.mat
#   inflating: test_set_sec1/points/0810.mat
#   inflating: __MACOSX/test_set_sec1/points/._0810.mat
#   inflating: test_set_sec1/points/2236.mat
#   inflating: __MACOSX/test_set_sec1/points/._2236.mat
#   inflating: test_set_sec1/points/0421.mat
#   inflating: __MACOSX/test_set_sec1/points/._0421.mat
#   inflating: test_set_sec1/points/0347.mat
#   inflating: __MACOSX/test_set_sec1/points/._0347.mat
#   inflating: test_set_sec1/points/1059.mat
#   inflating: __MACOSX/test_set_sec1/points/._1059.mat
#   inflating: test_set_sec1/points/0353.mat
#   inflating: __MACOSX/test_set_sec1/points/._0353.mat
#   inflating: test_set_sec1/points/0435.mat
#   inflating: __MACOSX/test_set_sec1/points/._0435.mat
#   inflating: test_set_sec1/points/2222.mat
#   inflating: __MACOSX/test_set_sec1/points/._2222.mat
#   inflating: test_set_sec1/points/1703.mat
#   inflating: __MACOSX/test_set_sec1/points/._1703.mat
#   inflating: test_set_sec1/points/1065.mat
#   inflating: __MACOSX/test_set_sec1/points/._1065.mat
#   inflating: test_set_sec1/points/1071.mat
#   inflating: __MACOSX/test_set_sec1/points/._1071.mat
#   inflating: test_set_sec1/points/1717.mat
#   inflating: __MACOSX/test_set_sec1/points/._1717.mat
#   inflating: test_set_sec1/points/0409.mat
#   inflating: __MACOSX/test_set_sec1/points/._0409.mat
#   inflating: test_set_sec1/points/1924.mat
#   inflating: __MACOSX/test_set_sec1/points/._1924.mat
#   inflating: test_set_sec1/points/0384.mat
#   inflating: __MACOSX/test_set_sec1/points/._0384.mat
#   inflating: test_set_sec1/points/0390.mat
#   inflating: __MACOSX/test_set_sec1/points/._0390.mat
#   inflating: test_set_sec1/points/1930.mat
#   inflating: __MACOSX/test_set_sec1/points/._1930.mat
#   inflating: test_set_sec1/points/1918.mat
#   inflating: __MACOSX/test_set_sec1/points/._1918.mat

# %%
## points
points_path_final = 'test_set_sec1/points'
points_final = [p for p in sorted(os.listdir(points_path_final))]
all_points_final = []
for p in points_final:
  poiFile_final = os.path.join(points_path_final, p)
  poi_final = scio.loadmat(poiFile_final)
  poi_final = OrderedDict(poi_final)
  all_points_final.append(poi_final.popitem()[1])

print('success')
# Out:
# success

# %%
########## Calculating pairwise distance ##########
pair_dist_final = []
for i in range(len(all_points_final)):
  pair_dist_final.append(metrics.pairwise_distances(all_points_final[i])[np.triu_indices(78)])

# %% [markdown]
# #### GBM

# %%
gbm_final=joblib.load("gbm_trained.m")

start_gbm = time.time()
pred_gbm_final = gbm_final.predict(pair_dist_final)
finish_gbm = time.time()
print(pred_gbm_final)
# Out:
# [22  7  9 ...  4 20 19]

# %%
gbm = np.asarray(pred_gbm_final)
np.savetxt("gbm_final_result.csv", gbm, delimiter=",")

# %% [markdown]
# #### XGBOOST

# %%
xgb_final=joblib.load("xgb_final.m")

start_xgb = time.time()
preds_xgb_final = xgb_final.predict(pair_dist_final)
finish_xgb = time.time()
print(preds_xgb_final)
# Out:
# [22  7  9 ...  4 19 19]

# %%
xgb = np.asarray(preds_xgb_final)
np.savetxt("xgb_final_result.csv", xgb, delimiter=",")

# %% [markdown]
# #### SVM

# %%
########## Scaling datasets ##########
points_test_np_final = np.array(pair_dist_final)
points_test_scale_final = scale(points_test_np_final)

# %%
svm_final=joblib.load("svm_final.m")
start_svm = time.time()
y_pred_svm_final = svm_final.predict(points_test_scale_final)
finish_svm = time.time()
print(y_pred_svm_final)
# Out:
# [22  7  9 ...  4 19 21]

# %%
svm = np.asarray(y_pred_svm_final)
np.savetxt("svm_final_result.csv", svm, delimiter=",")

# %% [markdown]
# # Summarize Running Time

# %%
print("Time：%f s" %(finish_gbm-start_gbm)) # GBM
print("Time：%f s" %(finish_xgb-start_xgb)) # XGBOOST
print("Time：%f s" %(finish_svm-start_svm)) # SVM
# Out:
# Time：0.358157 s
# Time：2.750383 s
# Time：32.181925 s
